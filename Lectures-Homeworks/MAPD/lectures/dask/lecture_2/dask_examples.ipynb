# %% [markdown]
# ## Command Line
#
#
# This is the most fundamental way to deploy Dask on multiple machines. In production environments, this process is often automated by some other resource manager. Hence, it is rare that people need to follow these instructions explicitly. But since we want learn how to "build" a cluster we want study how to start it from the command line.
#
# A ```dask.distributed``` network consists of one ```dask-scheduler``` process and several ```dask-worker``` processes that connect to that scheduler. These are normal Python processes that can be executed from the command line. We launch the dask-scheduler executable in one process and the dask-worker executable in several processes, possibly on different machines.

# %% [markdown]
# Hence, respect to the revious lectures, today we want to create a cluster "from scratch" using IP addresses and real workers and not the automatic "local cluster" created by dask.

# %% [markdown]
# At first let's see how works the ```dask-scheduler``` command

# %%
# %%bash
#
# dask-scheduler --help
# Out:
# Usage: dask-scheduler [OPTIONS] [PRELOAD_ARGV]...
#
# Options:
#   --host TEXT                   URI, IP or hostname of this server
#   --port INTEGER                Serving port
#   --interface TEXT              Preferred network interface like 'eth0' or
#                                 'ib0'
#   --protocol TEXT               Protocol like tcp, tls, or ucx
#   --tls-ca-file PATH            CA cert(s) file for TLS (in PEM format)
#   --tls-cert PATH               certificate file for TLS (in PEM format)
#   --tls-key PATH                private key file for TLS (in PEM format)
#   --bokeh-port INTEGER          Deprecated.  See --dashboard-address
#   --dashboard-address TEXT      Address on which to listen for diagnostics
#                                 dashboard  [default: :8787]
#   --dashboard / --no-dashboard  Launch the Dashboard [default: --dashboard]
#   --bokeh / --no-bokeh          Deprecated.  See --dashboard/--no-dashboard.
#   --show / --no-show            Show web UI [default: --show]
#   --dashboard-prefix TEXT       Prefix for the dashboard app
#   --use-xheaders BOOLEAN        User xheaders in dashboard app for ssl
#                                 termination in header  [default: False]
#   --pid-file TEXT               File to write the process PID
#   --scheduler-file TEXT         File to write connection information. This may
#                                 be a good way to share connection information
#                                 if your cluster is on a shared network file
#                                 system.
#   --preload TEXT                Module that should be loaded by the scheduler
#                                 process  like "foo.bar" or "/path/to/foo.py".
#   --idle-timeout TEXT           Time of inactivity after which to kill the
#                                 scheduler
#   --version                     Show the version and exit.
#   --help                        Show this message and exit.

# %%
# %%bash
#
# #dask-scheduler run it inside a real bash terminal not from jupyter

# %% [markdown]
# The command ```dask-worker``` on the rest of the nodes. Let's see how it works:

# %%
# %%bash
#
# dask-worker --help
# Out:
# Usage: dask-worker [OPTIONS] [SCHEDULER] [PRELOAD_ARGV]...
#
# Options:
#   --tls-ca-file PATH              CA cert(s) file for TLS (in PEM format)
#   --tls-cert PATH                 certificate file for TLS (in PEM format)
#   --tls-key PATH                  private key file for TLS (in PEM format)
#   --worker-port TEXT              Serving computation port, defaults to
#                                   random. When creating multiple workers with
#                                   --nprocs, a sequential range of worker ports
#                                   may be used by specifying the first and last
#                                   available ports like <first-port>:<last-
#                                   port>. For example, --worker-port=3000:3026
#                                   will use ports 3000, 3001, ..., 3025, 3026.
#   --nanny-port TEXT               Serving nanny port, defaults to random. When
#                                   creating multiple nannies with --nprocs, a
#                                   sequential range of nanny ports may be used
#                                   by specifying the first and last available
#                                   ports like <first-port>:<last-port>. For
#                                   example, --nanny-port=3000:3026 will use
#                                   ports 3000, 3001, ..., 3025, 3026.
#   --bokeh-port INTEGER            Deprecated.  See --dashboard-address
#   --dashboard-address TEXT        Address on which to listen for diagnostics
#                                   dashboard
#   --dashboard / --no-dashboard    Launch the Dashboard [default: --dashboard]
#   --bokeh / --no-bokeh            Deprecated.  See --dashboard/--no-dashboard.
#   --listen-address TEXT           The address to which the worker binds.
#                                   Example: tcp://0.0.0.0:9000
#   --contact-address TEXT          The address the worker advertises to the
#                                   scheduler for communication with it and
#                                   other workers. Example: tcp://127.0.0.1:9000
#   --host TEXT                     Serving host. Should be an ip address that
#                                   is visible to the scheduler and other
#                                   workers. See --listen-address and --contact-
#                                   address if you need different listen and
#                                   contact addresses. See --interface.
#   --interface TEXT                Network interface like 'eth0' or 'ib0'
#   --protocol TEXT                 Protocol like tcp, tls, or ucx
#   --nthreads INTEGER              Number of threads per process.
#   --nprocs TEXT                   Number of worker processes to launch. If
#                                   negative, then (CPU_COUNT + 1 + nprocs) is
#                                   used. Set to 'auto' to set nprocs and
#                                   nthreads dynamically based on CPU_COUNT
#                                   [default: 1]
#   --name TEXT                     A unique name for this worker like
#                                   'worker-1'. If used with --nprocs then the
#                                   process number will be appended like name-0,
#                                   name-1, name-2, ...
#   --memory-limit TEXT
#                                   Bytes of memory per process that the
#                                   worker can use.
#                                   This can be:
#                                   - an integer
#                                   (bytes), note 0 is a special case for no
#                                   memory management.
#                                   - a float (fraction of
#                                   total system memory).
#                                   - a string (like 5GB
#                                   or 5000M).
#                                   - 'auto' for automatically
#                                   computing the memory limit.  [default: auto]
#   --reconnect / --no-reconnect    Reconnect to scheduler if disconnected
#                                   [default: --reconnect]
#   --nanny / --no-nanny            Start workers in nanny process for
#                                   management [default: --nanny]
#   --pid-file TEXT                 File to write the process PID
#   --local-directory TEXT          Directory to place worker files
#   --resources TEXT                Resources for task constraints like "GPU=2
#                                   MEM=10e9". Resources are applied separately
#                                   to each worker process (only relevant when
#                                   starting multiple worker processes with '--
#                                   nprocs').
#   --scheduler-file TEXT           Filename to JSON encoded scheduler
#                                   information. Use with dask-scheduler
#                                   --scheduler-file
#   --death-timeout TEXT            Seconds to wait for a scheduler before
#                                   closing
#   --dashboard-prefix TEXT         Prefix for the dashboard
#   --lifetime TEXT                 If provided, shut down the worker after this
#                                   duration.
#   --lifetime-stagger TEXT         Random amount by which to stagger lifetime
#                                   values  [default: 0 seconds]
#   --worker-class TEXT             Worker class used to instantiate workers
#                                   from.  [default: dask.distributed.Worker]
#   --lifetime-restart / --no-lifetime-restart
#                                   Whether or not to restart the worker after
#                                   the lifetime lapses. This assumes that you
#                                   are using the --lifetime and --nanny
#                                   keywords  [default: False]
#   --preload TEXT                  Module that should be loaded by each worker
#                                   process like "foo.bar" or "/path/to/foo.py"
#   --preload-nanny TEXT            Module that should be loaded by each nanny
#                                   like "foo.bar" or "/path/to/foo.py"
#   --version                       Show the version and exit.
#   --help                          Show this message and exit.

# %% [markdown]
# Thisn command must be run by providing the address to the node that hosts ```dask-scheduler```:

# %%
# %%bash
# #dask-worker 192.168.1.12:8687 run int inside the real command line not from jupyter

# %% [markdown]
# ### Basic concepts
# The scheduler and workers both need to accept TCP connections on an open port. By default, the scheduler binds to port 8786 and the worker binds to a random open port. If you are behind a firewall then you may have to open particular ports or tell Dask on a different port.
#
# Dask workers are run within a *nanny* process that *monitors* the worker process and restarts it if necessary.
#
# As we have saw last lecture, Dask schedulers and even workers host interactive diagnostic web servers using the Bokeh server. These are optional, but generally useful to users. The diagnostic server on the scheduler is particularly valuable, and is served on port 8787.

# %% [markdown]
# ### Try to create a your first cluster

# %% [markdown]
# At first run the cell below in order to indentify your network-card and what your IP is:

# %%
# %%bash
#
# ifconfig ##only for those of you that does not use the docker cluster
# Out:
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         inet6 ::1  prefixlen 128  scopeid 0x10<host>
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 333318  bytes 135236769 (135.2 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 333318  bytes 135236769 (135.2 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# wlp1s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 10.4.51.1  netmask 255.255.255.252  broadcast 10.4.51.3
#         inet6 fe80::4be3:10e8:6a10:e891  prefixlen 64  scopeid 0x20<link>
#         ether 48:f1:7f:76:de:82  txqueuelen 1000  (Ethernet)
#         RX packets 649635  bytes 932589943 (932.5 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 67685  bytes 7244369 (7.2 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

# %% [markdown]
# Now open you command line and run:

# %%
#dask-scheduler --host IP --port 8786

# %% [markdown]
# At this point open another command line and run this command:

# %%
#dask-worker IP:8786 --nprocs 2 #this command create 2 workers

# %% [markdown]
# when is all up to date try to connect to the dashboard and take a look to your new cluster!
# If you have install all the packages in the correct way you should be able to access to the dashboard at: IP:8787

# %% [markdown]
# ### Run an old exercise over the new cluster
#
# Try to count how many words are present in all the documents over the cluster.

# %%
from sklearn.datasets import fetch_20newsgroups
from dask.distributed import Client
import time

categories = [
     'comp.graphics',
     'comp.os.ms-windows.misc',
     'comp.sys.ibm.pc.hardware',
     'comp.sys.mac.hardware',
     'comp.windows.x',
     'misc.forsale',
     'rec.autos',
     'rec.motorcycles',
     'rec.sport.baseball',
     'rec.sport.hockey',
     'sci.crypt',
     'sci.electronics',
     'sci.med',
     'sci.space'
]

dataset = fetch_20newsgroups(subset='train', categories=categories ).data

print("Texts document present on the dataset: "+str(len(dataset)))

def count_word_in_statement(text):
    """
    This function takes a text as input and return the number of the words that it contains
    """
    #time.sleep(0.1)
    splitted_words = text.split()
    return len(splitted_words)
# Out:
# Texts document present on the dataset: 8283

# %% [markdown]
# Sequential code:

# %%
import time
start = time.time()


total_words_in_all_data = 0
for index in range(0, len(dataset)):
    total_words_in_all_data = total_words_in_all_data + count_word_in_statement(dataset[index])

    
end = time.time()
print("Total word in the dataset: {}".format(total_words_in_all_data))
print("Computation took {}s".format(end-start))
# Out:
# Total word in the dataset: 2038444
# Computation took 0.10924959182739258s

# %% [markdown]
# Distributed code:

# %%
client = Client() #change your setting

# %%
import time
start = time.time()

#futures = client.map(count_word_in_statement, dataset)
futures = [client.submit(count_word_in_statement, data) for data in dataset]

futures = client.submit(sum, futures)
total_words_in_all_data = client.gather(futures)

    
end = time.time()
print("Total word in the dataset: {}".format(total_words_in_all_data))
print("Computation took {}s".format(end-start))
# Out:
# Total word in the dataset: 2038444
# Computation took 8.460427522659302s

# %%
client.close()

# %% [markdown]
# ### Why in this case sequential code took more than 10 times les than ditributed version?
#
# In general when yuo have to deal with a cluster you have to think about the *overhead*.
#
# You can image the overhead like the the computational time necessary to process your data.
# Typically in a cluster there two kind of overhead:
# + scheduler overhead in serializing the objects that must be sent to workers
# + connection overhead. The speed of the network connection between the cluster nodes
#
# In the first case, the scheduler adds about one millisecond of overhead per task or Future object. Despite this may sound fast or inconsequential, it's quite slow if you run a large number of tasks. Under this perspective, a larger number of the task means a larger amount of time to create the Future objects of the tasks.
# In the light of above, if your functions run faster than 100ms or so then you might not see any
# speedup from using distributed computing, but even worse, probably you might see that the performances get worse.
#
# In the second case things are different. The connection overhead may depends from several factors including the stability of the network, the type (wired or WiFi or optic fibe), and bandwith of the network.
#
# This is what is happening in the previous example.
#
# Let's try to introduce a simulation of intesive computation (a sleep of 10ms: 10 times less the the overhead generated by dask-scheduler):

# %%
def count_word_in_statement(text):
    """
    This function takes a text as input and return the number of the words that it contains
    """
    splitted_words = text.split()
    time.sleep(0.01)
    return len(splitted_words)

# %% [markdown]
# Try to run and wait the sequantial code:

# %%
import time
start = time.time()


total_words_in_all_data = 0
for index in range(0, len(dataset)):
    total_words_in_all_data = total_words_in_all_data + count_word_in_statement(dataset[index])
    end = time.time() - start
    if end >= 50:
        print("More than {}s of computation time...".format(end))

    
end = time.time()
print("Total word in the dataset: {}".format(total_words_in_all_data))
print("Computation took {}s".format(end-start))
# Out:
# More than 50.00693130493164s of computation time...
# More than 50.01743984222412s of computation time...
# More than 50.02785897254944s of computation time...
# More than 50.038312673568726s of computation time...
# More than 50.048792362213135s of computation time...
# More than 50.0592885017395s of computation time...
# More than 50.06975722312927s of computation time...
# More than 50.08012270927429s of computation time...
# More than 50.090423345565796s of computation time...
# More than 50.1008186340332s of computation time...
# More than 50.11118769645691s of computation time...
# More than 50.12155818939209s of computation time...
# More than 50.13215613365173s of computation time...
# More than 50.142539501190186s of computation time...
# More than 50.15362548828125s of computation time...
# More than 50.16425824165344s of computation time...
# More than 50.1750214099884s of computation time...
# More than 50.185537338256836s of computation time...
# More than 50.1962833404541s of computation time...
# More than 50.20710349082947s of computation time...
# More than 50.21796917915344s of computation time...
# More than 50.228665351867676s of computation time...
# More than 50.23913025856018s of computation time...
# More than 50.24979615211487s of computation time...
# More than 50.26080632209778s of computation time...
# More than 50.271612882614136s of computation time...
# More than 50.28192853927612s of computation time...
# More than 50.29222631454468s of computation time...
# More than 50.30246090888977s of computation time...
# More than 50.31291341781616s of computation time...
# More than 50.32322120666504s of computation time...
# More than 50.333714723587036s of computation time...
# More than 50.344016313552856s of computation time...
# More than 50.35435342788696s of computation time...
# More than 50.364672899246216s of computation time...
# More than 50.374988079071045s of computation time...
# More than 50.385292530059814s of computation time...
# More than 50.39563465118408s of computation time...
# More than 50.40597915649414s of computation time...
# More than 50.416648387908936s of computation time...
# More than 50.427186250686646s of computation time...
# More than 50.437623262405396s of computation time...
# More than 50.448139667510986s of computation time...
# More than 50.458635330200195s of computation time...
# More than 50.46886920928955s of computation time...
# More than 50.4792058467865s of computation time...
# More than 50.48946738243103s of computation time...
# More than 50.499948024749756s of computation time...
# More than 50.510310649871826s of computation time...
# More than 50.520554304122925s of computation time...
# More than 50.5307891368866s of computation time...
# More than 50.54112148284912s of computation time...
# More than 50.551618576049805s of computation time...
# More than 50.56198453903198s of computation time...
# More than 50.57232737541199s of computation time...
# More than 50.582748889923096s of computation time...
# More than 50.593302965164185s of computation time...
# More than 50.60361623764038s of computation time...
# More than 50.61400628089905s of computation time...
# More than 50.62453484535217s of computation time...
# More than 50.634883403778076s of computation time...
# More than 50.64536261558533s of computation time...
# More than 50.65580177307129s of computation time...
# More than 50.66647171974182s of computation time...
# More than 50.67731690406799s of computation time...
# More than 50.68815612792969s of computation time...
# More than 50.69861555099487s of computation time...
# More than 50.70925688743591s of computation time...
# More than 50.7196626663208s of computation time...
# More than 50.73019456863403s of computation time...
# More than 50.74058294296265s of computation time...
# More than 50.75122261047363s of computation time...
# More than 50.76178693771362s of computation time...
# More than 50.772122859954834s of computation time...
# More than 50.78248906135559s of computation time...
# More than 50.79310369491577s of computation time...
# More than 50.803420305252075s of computation time...
# More than 50.81383228302002s of computation time...
# More than 50.82423114776611s of computation time...
# More than 50.83472657203674s of computation time...
# More than 50.84510374069214s of computation time...
# More than 50.85592746734619s of computation time...
# More than 50.866472482681274s of computation time...
# More than 50.876935720443726s of computation time...
# More than 50.88746213912964s of computation time...
# More than 50.89778542518616s of computation time...
# More than 50.90812015533447s of computation time...
# More than 50.91846418380737s of computation time...
# More than 50.9291353225708s of computation time...
# More than 50.939512968063354s of computation time...
# More than 50.94983243942261s of computation time...
# More than 50.96037554740906s of computation time...
# More than 50.970707654953s of computation time...
# More than 50.981531620025635s of computation time...
# More than 50.99203372001648s of computation time...
# More than 51.00239658355713s of computation time...
# More than 51.01277041435242s of computation time...
# More than 51.02327275276184s of computation time...
# More than 51.03396153450012s of computation time...
# More than 51.04435110092163s of computation time...
# More than 51.054686546325684s of computation time...
# More than 51.06507992744446s of computation time...
# More than 51.0756299495697s of computation time...
# More than 51.0858371257782s of computation time...
# More than 51.09616255760193s of computation time...
# More than 51.10637879371643s of computation time...
# More than 51.11660027503967s of computation time...
# More than 51.12681007385254s of computation time...
# More than 51.137113094329834s of computation time...
# More than 51.147411584854126s of computation time...
# More than 51.15767502784729s of computation time...
# More than 51.16807198524475s of computation time...
# More than 51.17836594581604s of computation time...
# More than 51.188597440719604s of computation time...
# More than 51.199203968048096s of computation time...
# More than 51.20992851257324s of computation time...
# More than 51.22022533416748s of computation time...
# More than 51.2305793762207s of computation time...
# More than 51.24083065986633s of computation time...
# More than 51.251251459121704s of computation time...
# More than 51.26187348365784s of computation time...
# More than 51.27212452888489s of computation time...
# More than 51.28250813484192s of computation time...
# More than 51.293357610702515s of computation time...
# More than 51.30376672744751s of computation time...
# More than 51.31433176994324s of computation time...
# More than 51.325024366378784s of computation time...
# More than 51.33524560928345s of computation time...
# More than 51.345552921295166s of computation time...
# More than 51.3558394908905s of computation time...
# More than 51.366204261779785s of computation time...
# More than 51.37651824951172s of computation time...
# More than 51.38676381111145s of computation time...
# More than 51.39711284637451s of computation time...
# More than 51.40742778778076s of computation time...
# More than 51.4177303314209s of computation time...
# More than 51.428062438964844s of computation time...
# More than 51.4384069442749s of computation time...
# More than 51.449012994766235s of computation time...
# More than 51.459506034851074s of computation time...
# More than 51.469775676727295s of computation time...
# More than 51.480077266693115s of computation time...
# More than 51.49038577079773s of computation time...
# More than 51.50066113471985s of computation time...
# More than 51.51106810569763s of computation time...
# More than 51.52138829231262s of computation time...
# More than 51.53210163116455s of computation time...
# More than 51.54271411895752s of computation time...
# More than 51.55321669578552s of computation time...
# More than 51.563570499420166s of computation time...
# More than 51.57386755943298s of computation time...
# More than 51.58418369293213s of computation time...
# More than 51.594470262527466s of computation time...
# More than 51.60482978820801s of computation time...
# More than 51.61526584625244s of computation time...
# More than 51.625954151153564s of computation time...
# More than 51.63636589050293s of computation time...
# More than 51.64688777923584s of computation time...
# More than 51.6573965549469s of computation time...
# More than 51.667985916137695s of computation time...
# More than 51.67832136154175s of computation time...
# More than 51.688660621643066s of computation time...
# More than 51.69953989982605s of computation time...
# More than 51.70994687080383s of computation time...
# More than 51.72026300430298s of computation time...
# More than 51.73065805435181s of computation time...
# More than 51.74120020866394s of computation time...
# More than 51.75148558616638s of computation time...
# More than 51.761849880218506s of computation time...
# More than 51.772300720214844s of computation time...
# More than 51.782801151275635s of computation time...
# More than 51.793100357055664s of computation time...
# More than 51.803548097610474s of computation time...
# More than 51.81402349472046s of computation time...
# More than 51.82440376281738s of computation time...
# More than 51.834795236587524s of computation time...
# More than 51.845295906066895s of computation time...
# More than 51.85593628883362s of computation time...
# More than 51.866432189941406s of computation time...
# More than 51.877142667770386s of computation time...
# More than 51.887542963027954s of computation time...
# More than 51.89800763130188s of computation time...
# More than 51.90878891944885s of computation time...
# More than 51.91916346549988s of computation time...
# More than 51.92951250076294s of computation time...
# More than 51.939841985702515s of computation time...
# More than 51.9500949382782s of computation time...
# More than 51.960471630096436s of computation time...
# More than 51.97082853317261s of computation time...
# More than 51.981056690216064s of computation time...
# More than 51.99132299423218s of computation time...
# More than 52.00159430503845s of computation time...
# More than 52.0118944644928s of computation time...
# More than 52.02244710922241s of computation time...
# More than 52.032745599746704s of computation time...
# More than 52.043155908584595s of computation time...
# More than 52.053476333618164s of computation time...
# More than 52.06386661529541s of computation time...
# More than 52.074450731277466s of computation time...
# More than 52.08479356765747s of computation time...
# More than 52.09518122673035s of computation time...
# More than 52.105597257614136s of computation time...
# More than 52.11608052253723s of computation time...
# More than 52.12644076347351s of computation time...
# More than 52.136842250823975s of computation time...
# More than 52.14723515510559s of computation time...
# More than 52.15765333175659s of computation time...
# More than 52.16803598403931s of computation time...
# More than 52.178335428237915s of computation time...
# More than 52.18866801261902s of computation time...
# More than 52.199037075042725s of computation time...
# More than 52.20975041389465s of computation time...
# More than 52.22025203704834s of computation time...
# More than 52.230735301971436s of computation time...
# More than 52.24124836921692s of computation time...
# More than 52.25170922279358s of computation time...
# More than 52.262197732925415s of computation time...
# More than 52.2726788520813s of computation time...
# More than 52.28396439552307s of computation time...
# More than 52.29465937614441s of computation time...
# More than 52.305248737335205s of computation time...
# More than 52.31571435928345s of computation time...
# More than 52.32621431350708s of computation time...
# More than 52.33653521537781s of computation time...
# More than 52.34679937362671s of computation time...
# More than 52.357093334198s of computation time...
# More than 52.36737942695618s of computation time...
# More than 52.37775993347168s of computation time...
# More than 52.38808608055115s of computation time...
# More than 52.39850068092346s of computation time...
# More than 52.40885043144226s of computation time...
# More than 52.41920232772827s of computation time...
# More than 52.429579973220825s of computation time...
# More than 52.43988490104675s of computation time...
# More than 52.450172662734985s of computation time...
# More than 52.460569620132446s of computation time...
# More than 52.470948219299316s of computation time...
# More than 52.48159885406494s of computation time...
# More than 52.492159366607666s of computation time...
# More than 52.50250506401062s of computation time...
# More than 52.51294422149658s of computation time...
# More than 52.52332782745361s of computation time...
# More than 52.53368926048279s of computation time...
# More than 52.54406213760376s of computation time...
# More than 52.554266929626465s of computation time...
# More than 52.564855098724365s of computation time...
# More than 52.57526350021362s of computation time...
# More than 52.5855610370636s of computation time...
# More than 52.595839738845825s of computation time...
# More than 52.606051445007324s of computation time...
# More than 52.61663603782654s of computation time...
# More than 52.62707996368408s of computation time...
# More than 52.637495279312134s of computation time...
# More than 52.64819288253784s of computation time...
# More than 52.658782958984375s of computation time...
# More than 52.66920804977417s of computation time...
# More than 52.68020057678223s of computation time...
# More than 52.69118905067444s of computation time...
# More than 52.70182824134827s of computation time...
# More than 52.71221375465393s of computation time...
# More than 52.72252583503723s of computation time...
# More than 52.732996463775635s of computation time...
# More than 52.74331307411194s of computation time...
# More than 52.75363254547119s of computation time...
# More than 52.7640323638916s of computation time...
# More than 52.774635791778564s of computation time...
# More than 52.78513288497925s of computation time...
# More than 52.79549050331116s of computation time...
# More than 52.80585527420044s of computation time...
# More than 52.816203117370605s of computation time...
# More than 52.82666635513306s of computation time...
# More than 52.837125301361084s of computation time...
# More than 52.84755349159241s of computation time...
# More than 52.85864973068237s of computation time...
# More than 52.86895942687988s of computation time...
# More than 52.87924361228943s of computation time...
# More than 52.889533042907715s of computation time...
# More than 52.89996957778931s of computation time...
# More than 52.910314083099365s of computation time...
# More than 52.920628786087036s of computation time...
# More than 52.93102765083313s of computation time...
# More than 52.94235014915466s of computation time...
# More than 52.952670097351074s of computation time...
# More than 52.96305966377258s of computation time...
# More than 52.97336006164551s of computation time...
# More than 52.98370862007141s of computation time...
# More than 52.994086027145386s of computation time...
# More than 53.00436782836914s of computation time...
# More than 53.01470875740051s of computation time...
# More than 53.02527379989624s of computation time...
# More than 53.03565192222595s of computation time...
# More than 53.046014070510864s of computation time...
# More than 53.05631113052368s of computation time...
# More than 53.06662034988403s of computation time...
# More than 53.07709741592407s of computation time...
# More than 53.08808398246765s of computation time...
# More than 53.098581314086914s of computation time...
# More than 53.10887408256531s of computation time...
# More than 53.1192102432251s of computation time...
# More than 53.12956142425537s of computation time...
# More than 53.14002776145935s of computation time...
# More than 53.15036392211914s of computation time...
# More than 53.16074514389038s of computation time...
# More than 53.17105507850647s of computation time...
# More than 53.18145203590393s of computation time...
# More than 53.191874742507935s of computation time...
# More than 53.202186584472656s of computation time...
# More than 53.21282172203064s of computation time...
# More than 53.223224401474s of computation time...
# More than 53.2336950302124s of computation time...
# More than 53.244065046310425s of computation time...
# More than 53.254334926605225s of computation time...
# More than 53.264790296554565s of computation time...
# More than 53.27515411376953s of computation time...
# More than 53.285515546798706s of computation time...
# More than 53.29584097862244s of computation time...
# More than 53.30615282058716s of computation time...
# More than 53.31655144691467s of computation time...
# More than 53.32686161994934s of computation time...
# More than 53.337220430374146s of computation time...
# More than 53.34764838218689s of computation time...
# More than 53.35813856124878s of computation time...
# More than 53.36851119995117s of computation time...
# More than 53.378875494003296s of computation time...
# More than 53.38925766944885s of computation time...
# More than 53.39965605735779s of computation time...
# More than 53.40996026992798s of computation time...
# More than 53.42028069496155s of computation time...
# More than 53.430726766586304s of computation time...
# More than 53.44148254394531s of computation time...
# More than 53.45193076133728s of computation time...
# More than 53.46226477622986s of computation time...
# More than 53.47256803512573s of computation time...
# More than 53.4829306602478s of computation time...
# More than 53.49328589439392s of computation time...
# More than 53.50372672080994s of computation time...
# More than 53.514206647872925s of computation time...
# More than 53.524691343307495s of computation time...
# More than 53.53504776954651s of computation time...
# More than 53.545472383499146s of computation time...
# More than 53.55604672431946s of computation time...
# More than 53.5669960975647s of computation time...
# More than 53.577348470687866s of computation time...
# More than 53.58781051635742s of computation time...
# More than 53.59846091270447s of computation time...
# More than 53.608750104904175s of computation time...
# More than 53.61898756027222s of computation time...
# More than 53.62929320335388s of computation time...
# More than 53.639726638793945s of computation time...
# More than 53.649943113327026s of computation time...
# More than 53.66027092933655s of computation time...
# More than 53.67051577568054s of computation time...
# More than 53.68100190162659s of computation time...
# More than 53.69137191772461s of computation time...
# More than 53.70179891586304s of computation time...
# More than 53.712095975875854s of computation time...
# More than 53.722407817840576s of computation time...
# More than 53.73271608352661s of computation time...
# More than 53.74323749542236s of computation time...
# More than 53.75360369682312s of computation time...
# More than 53.76417255401611s of computation time...
# More than 53.774839639663696s of computation time...
# More than 53.785407304763794s of computation time...
# More than 53.7959258556366s of computation time...
# More than 53.80643105506897s of computation time...
# More than 53.81663751602173s of computation time...
# More than 53.82693576812744s of computation time...
# More than 53.837103605270386s of computation time...
# More than 53.84734392166138s of computation time...
# More than 53.857616662979126s of computation time...
# More than 53.867833852767944s of computation time...
# More than 53.878058433532715s of computation time...
# More than 53.88831162452698s of computation time...
# More than 53.89850616455078s of computation time...
# More than 53.90879940986633s of computation time...
# More than 53.91905331611633s of computation time...
# More than 53.92930746078491s of computation time...
# More than 53.9396915435791s of computation time...
# More than 53.95016932487488s of computation time...
# More than 53.96059608459473s of computation time...
# More than 53.971529960632324s of computation time...
# More than 53.9818549156189s of computation time...
# More than 53.992289781570435s of computation time...
# More than 54.00310230255127s of computation time...
# More than 54.01405596733093s of computation time...
# More than 54.02491641044617s of computation time...
# More than 54.03528809547424s of computation time...
# More than 54.04566407203674s of computation time...
# More than 54.056079626083374s of computation time...
# More than 54.06640815734863s of computation time...
# More than 54.076770544052124s of computation time...
# More than 54.087109327316284s of computation time...
# More than 54.09757089614868s of computation time...
# More than 54.108025312423706s of computation time...
# More than 54.118431091308594s of computation time...
# More than 54.1289165019989s of computation time...
# More than 54.13939571380615s of computation time...
# More than 54.14978885650635s of computation time...
# More than 54.16021966934204s of computation time...
# More than 54.170610189437866s of computation time...
# More than 54.181031942367554s of computation time...
# More than 54.19150114059448s of computation time...
# More than 54.20221257209778s of computation time...
# More than 54.21272158622742s of computation time...
# More than 54.22307872772217s of computation time...
# More than 54.23348069190979s of computation time...
# More than 54.24392008781433s of computation time...
# More than 54.254358530044556s of computation time...
# More than 54.26482939720154s of computation time...
# More than 54.275224447250366s of computation time...
# More than 54.286630630493164s of computation time...
# More than 54.297964334487915s of computation time...
# More than 54.3084032535553s of computation time...
# More than 54.31874132156372s of computation time...
# More than 54.329267740249634s of computation time...
# More than 54.33979344367981s of computation time...
# More than 54.35012698173523s of computation time...
# More than 54.36068344116211s of computation time...
# More than 54.37111735343933s of computation time...
# More than 54.38166260719299s of computation time...
# More than 54.39204716682434s of computation time...
# More than 54.40234375s of computation time...
# More than 54.41285586357117s of computation time...
# More than 54.42340874671936s of computation time...
# More than 54.433751583099365s of computation time...
# More than 54.444087266922s of computation time...
# More than 54.45445680618286s of computation time...
# More than 54.464924335479736s of computation time...
# More than 54.47533655166626s of computation time...
# More than 54.48569297790527s of computation time...
# More than 54.49666213989258s of computation time...
# More than 54.50730776786804s of computation time...
# More than 54.51777958869934s of computation time...
# More than 54.52885723114014s of computation time...
# More than 54.5401496887207s of computation time...
# More than 54.55037188529968s of computation time...
# More than 54.560636043548584s of computation time...
# More than 54.57093334197998s of computation time...
# More than 54.58128070831299s of computation time...
# More than 54.591798543930054s of computation time...
# More than 54.60225510597229s of computation time...
# More than 54.61361837387085s of computation time...
# More than 54.62411379814148s of computation time...
# More than 54.6344780921936s of computation time...
# More than 54.64480447769165s of computation time...
# More than 54.65515327453613s of computation time...
# More than 54.66539692878723s of computation time...
# More than 54.67570114135742s of computation time...
# More than 54.68611454963684s of computation time...
# More than 54.6966016292572s of computation time...
# More than 54.70698833465576s of computation time...
# More than 54.71736240386963s of computation time...
# More than 54.727662563323975s of computation time...
# More than 54.737952709198s of computation time...
# More than 54.74833416938782s of computation time...
# More than 54.75871562957764s of computation time...
# More than 54.76913404464722s of computation time...
# More than 54.779640436172485s of computation time...
# More than 54.79016041755676s of computation time...
# More than 54.80056381225586s of computation time...
# More than 54.811010122299194s of computation time...
# More than 54.82144784927368s of computation time...
# More than 54.831969261169434s of computation time...
# More than 54.84235429763794s of computation time...
# More than 54.85269331932068s of computation time...
# More than 54.86378502845764s of computation time...
# More than 54.87409234046936s of computation time...
# More than 54.88438439369202s of computation time...
# More than 54.89469051361084s of computation time...
# More than 54.90498161315918s of computation time...
# More than 54.91529440879822s of computation time...
# More than 54.92565703392029s of computation time...
# More than 54.93598294258118s of computation time...
# More than 54.946439027786255s of computation time...
# More than 54.956735372543335s of computation time...
# More than 54.9670135974884s of computation time...
# More than 54.97734880447388s of computation time...
# More than 54.987659215927124s of computation time...
# More than 54.998034954071045s of computation time...
# More than 55.00837206840515s of computation time...
# More than 55.0188570022583s of computation time...
# More than 55.02930760383606s of computation time...
# More than 55.03997802734375s of computation time...
# More than 55.0504937171936s of computation time...
# More than 55.06087565422058s of computation time...
# More than 55.07133603096008s of computation time...
# More than 55.0817928314209s of computation time...
# More than 55.09220504760742s of computation time...
# More than 55.10249733924866s of computation time...
# More than 55.112993478775024s of computation time...
# More than 55.12336826324463s of computation time...
# More than 55.133721351623535s of computation time...
# More than 55.14414167404175s of computation time...
# More than 55.15477418899536s of computation time...
# More than 55.16533946990967s of computation time...
# More than 55.175724029541016s of computation time...
# More than 55.18610382080078s of computation time...
# More than 55.1966769695282s of computation time...
# More than 55.2072114944458s of computation time...
# More than 55.218425989151s of computation time...
# More than 55.22885751724243s of computation time...
# More than 55.239649534225464s of computation time...
# More than 55.25006365776062s of computation time...
# More than 55.2605619430542s of computation time...
# More than 55.27088785171509s of computation time...
# More than 55.28121089935303s of computation time...
# More than 55.29155349731445s of computation time...
# More than 55.30194425582886s of computation time...
# More than 55.312408208847046s of computation time...
# More than 55.32323861122131s of computation time...
# More than 55.33356547355652s of computation time...
# More than 55.34389305114746s of computation time...
# More than 55.35421800613403s of computation time...
# More than 55.36456036567688s of computation time...
# More than 55.374926805496216s of computation time...
# More than 55.38522005081177s of computation time...
# More than 55.39557909965515s of computation time...
# More than 55.406224727630615s of computation time...
# More than 55.41662287712097s of computation time...
# More than 55.426979303359985s of computation time...
# More than 55.43735885620117s of computation time...
# More than 55.44822597503662s of computation time...
# More than 55.45852732658386s of computation time...
# More than 55.46884775161743s of computation time...
# More than 55.479278326034546s of computation time...
# More than 55.48957562446594s of computation time...
# More than 55.49984097480774s of computation time...
# More than 55.510174036026s of computation time...
# More than 55.520575284957886s of computation time...
# More than 55.531086683273315s of computation time...
# More than 55.54145860671997s of computation time...
# More than 55.551812171936035s of computation time...
# More than 55.56245303153992s of computation time...
# More than 55.572869300842285s of computation time...
# More than 55.58323359489441s of computation time...
# More than 55.593552112579346s of computation time...
# More than 55.60389280319214s of computation time...
# More than 55.61427640914917s of computation time...
# More than 55.62471652030945s of computation time...
# More than 55.63505458831787s of computation time...
# More than 55.64544177055359s of computation time...
# More than 55.65609169006348s of computation time...
# More than 55.66640114784241s of computation time...
# More than 55.676793336868286s of computation time...
# More than 55.687190532684326s of computation time...
# More than 55.69753980636597s of computation time...
# More than 55.70799446105957s of computation time...
# More than 55.71833872795105s of computation time...
# More than 55.72880506515503s of computation time...
# More than 55.73929452896118s of computation time...
# More than 55.749642848968506s of computation time...
# More than 55.75998902320862s of computation time...
# More than 55.770381450653076s of computation time...
# More than 55.780911445617676s of computation time...
# More than 55.79136085510254s of computation time...
# More than 55.801727533340454s of computation time...
# More than 55.81214475631714s of computation time...
# More than 55.822765827178955s of computation time...
# More than 55.83308434486389s of computation time...
# More than 55.84344530105591s of computation time...
# More than 55.85380482673645s of computation time...
# More than 55.864246129989624s of computation time...
# More than 55.8746554851532s of computation time...
# More than 55.88497710227966s of computation time...
# More than 55.89555311203003s of computation time...
# More than 55.90597462654114s of computation time...
# More than 55.91629385948181s of computation time...
# More than 55.926682472229004s of computation time...
# More than 55.93703651428223s of computation time...
# More than 55.94734501838684s of computation time...
# More than 55.95766568183899s of computation time...
# More than 55.96808671951294s of computation time...
# More than 55.97842216491699s of computation time...
# More than 55.98878836631775s of computation time...
# More than 55.999245166778564s of computation time...
# More than 56.00967788696289s of computation time...
# More than 56.020071268081665s of computation time...
# More than 56.03048658370972s of computation time...
# More than 56.04086232185364s of computation time...
# More than 56.05117654800415s of computation time...
# More than 56.0615508556366s of computation time...
# More than 56.071934938430786s of computation time...
# More than 56.0824077129364s of computation time...
# More than 56.09280586242676s of computation time...
# More than 56.103208780288696s of computation time...
# More than 56.11404013633728s of computation time...
# More than 56.1246395111084s of computation time...
# More than 56.13514304161072s of computation time...
# More than 56.145652770996094s of computation time...
# More than 56.15641117095947s of computation time...
# More than 56.166868686676025s of computation time...
# More than 56.17747449874878s of computation time...
# More than 56.188371419906616s of computation time...
# More than 56.19900465011597s of computation time...
# More than 56.20955681800842s of computation time...
# More than 56.22004723548889s of computation time...
# More than 56.23051047325134s of computation time...
# More than 56.24093723297119s of computation time...
# More than 56.25130867958069s of computation time...
# More than 56.261841773986816s of computation time...
# More than 56.27489352226257s of computation time...
# More than 56.28725814819336s of computation time...
# More than 56.297664403915405s of computation time...
# More than 56.30828261375427s of computation time...
# More than 56.31860971450806s of computation time...
# More than 56.32890200614929s of computation time...
# More than 56.33942484855652s of computation time...
# More than 56.349735498428345s of computation time...
# More than 56.36017465591431s of computation time...
# More than 56.37050271034241s of computation time...
# More than 56.38075661659241s of computation time...
# More than 56.39175367355347s of computation time...
# More than 56.40218257904053s of computation time...
# More than 56.41283631324768s of computation time...
# More than 56.42335510253906s of computation time...
# More than 56.43385863304138s of computation time...
# More than 56.44445443153381s of computation time...
# More than 56.45506310462952s of computation time...
# More than 56.46540570259094s of computation time...
# More than 56.475754737854004s of computation time...
# More than 56.48621201515198s of computation time...
# More than 56.49753022193909s of computation time...
# More than 56.507930755615234s of computation time...
# More than 56.51870250701904s of computation time...
# More than 56.529555320739746s of computation time...
# More than 56.53997468948364s of computation time...
# More than 56.550525426864624s of computation time...
# More than 56.56086874008179s of computation time...
# More than 56.571396350860596s of computation time...
# More than 56.58174657821655s of computation time...
# More than 56.59213948249817s of computation time...
# More than 56.602476835250854s of computation time...
# More than 56.61309838294983s of computation time...
# More than 56.62344813346863s of computation time...
# More than 56.63379764556885s of computation time...
# More than 56.64414143562317s of computation time...
# More than 56.65480065345764s of computation time...
# More than 56.66512584686279s of computation time...
# More than 56.67546319961548s of computation time...
# More than 56.6858606338501s of computation time...
# More than 56.69930815696716s of computation time...
# More than 56.70960712432861s of computation time...
# More than 56.72006177902222s of computation time...
# More than 56.73064398765564s of computation time...
# More than 56.741037130355835s of computation time...
# More than 56.75139331817627s of computation time...
# More than 56.7619423866272s of computation time...
# More than 56.7723491191864s of computation time...
# More than 56.78266739845276s of computation time...
# More than 56.79302477836609s of computation time...
# More than 56.803380250930786s of computation time...
# More than 56.813732862472534s of computation time...
# More than 56.824142932891846s of computation time...
# More than 56.834503412246704s of computation time...
# More than 56.844871044158936s of computation time...
# More than 56.85521984100342s of computation time...
# More than 56.86557459831238s of computation time...
# More than 56.875956296920776s of computation time...
# More than 56.8863639831543s of computation time...
# More than 56.89688038825989s of computation time...
# More than 56.907280921936035s of computation time...
# More than 56.91765737533569s of computation time...
# More than 56.9280891418457s of computation time...
# More than 56.93840575218201s of computation time...
# More than 56.948657512664795s of computation time...
# More than 56.95907378196716s of computation time...
# More than 56.96941566467285s of computation time...
# More than 56.97969627380371s of computation time...
# More than 56.98998975753784s of computation time...
# More than 57.00036883354187s of computation time...
# More than 57.010906457901s of computation time...
# More than 57.02151966094971s of computation time...
# More than 57.031795263290405s of computation time...
# More than 57.042142391204834s of computation time...
# More than 57.052510023117065s of computation time...
# More than 57.0627601146698s of computation time...
# More than 57.07348394393921s of computation time...
# More than 57.08385419845581s of computation time...
# More than 57.09442687034607s of computation time...
# More than 57.10569882392883s of computation time...
# More than 57.11677408218384s of computation time...
# More than 57.12730360031128s of computation time...
# More than 57.138188123703s of computation time...
# More than 57.148417711257935s of computation time...
# More than 57.15870547294617s of computation time...
# More than 57.16897749900818s of computation time...
# More than 57.17924976348877s of computation time...
# More than 57.18957161903381s of computation time...
# More than 57.1999089717865s of computation time...
# More than 57.21118783950806s of computation time...
# More than 57.22155046463013s of computation time...
# More than 57.23178315162659s of computation time...
# More than 57.24215245246887s of computation time...
# More than 57.25247120857239s of computation time...
# More than 57.26273965835571s of computation time...
# More than 57.273094177246094s of computation time...
# More than 57.28344106674194s of computation time...
# More than 57.29399013519287s of computation time...
# More than 57.30602192878723s of computation time...
# More than 57.316521406173706s of computation time...
# More than 57.326974868774414s of computation time...
# More than 57.33780241012573s of computation time...
# More than 57.348193883895874s of computation time...
# More than 57.35842037200928s of computation time...
# More than 57.36870360374451s of computation time...
# More than 57.37893342971802s of computation time...
# More than 57.389204263687134s of computation time...
# More than 57.399465799331665s of computation time...
# More than 57.40972924232483s of computation time...
# More than 57.42020273208618s of computation time...
# More than 57.43057560920715s of computation time...
# More than 57.4410183429718s of computation time...
# More than 57.451592206954956s of computation time...
# More than 57.46225047111511s of computation time...
# More than 57.47267389297485s of computation time...
# More than 57.48299479484558s of computation time...
# More than 57.49339938163757s of computation time...
# More than 57.50392389297485s of computation time...
# More than 57.51418161392212s of computation time...
# More than 57.5245258808136s of computation time...
# More than 57.53489685058594s of computation time...
# More than 57.54520273208618s of computation time...
# More than 57.55553197860718s of computation time...
# More than 57.56585884094238s of computation time...
# More than 57.57613492012024s of computation time...
# More than 57.5865695476532s of computation time...
# More than 57.59683895111084s of computation time...
# More than 57.60721707344055s of computation time...
# More than 57.61762762069702s of computation time...
# More than 57.628535747528076s of computation time...
# More than 57.63913702964783s of computation time...
# More than 57.64954137802124s of computation time...
# More than 57.660019636154175s of computation time...
# More than 57.67138743400574s of computation time...
# More than 57.68182945251465s of computation time...
# More than 57.69304919242859s of computation time...
# More than 57.70384955406189s of computation time...
# More than 57.71446228027344s of computation time...
# More than 57.72493124008179s of computation time...
# More than 57.73533296585083s of computation time...
# More than 57.74602437019348s of computation time...
# More than 57.75648546218872s of computation time...
# More than 57.76677966117859s of computation time...
# More than 57.777331829071045s of computation time...
# More than 57.78764343261719s of computation time...
# More than 57.79789066314697s of computation time...
# More than 57.808268785476685s of computation time...
# More than 57.81856608390808s of computation time...
# More than 57.828954458236694s of computation time...
# More than 57.83941721916199s of computation time...
# More than 57.849770069122314s of computation time...
# More than 57.860174894332886s of computation time...
# More than 57.87077522277832s of computation time...
# More than 57.881176233291626s of computation time...
# More than 57.89173603057861s of computation time...
# More than 57.90214252471924s of computation time...
# More than 57.91280436515808s of computation time...
# More than 57.9231436252594s of computation time...
# More than 57.9334237575531s of computation time...
# More than 57.94381141662598s of computation time...
# More than 57.954254150390625s of computation time...
# More than 57.96475958824158s of computation time...
# More than 57.97511172294617s of computation time...
# More than 57.98543381690979s of computation time...
# More than 57.99576115608215s of computation time...
# More than 58.00609254837036s of computation time...
# More than 58.01641917228699s of computation time...
# More than 58.02672719955444s of computation time...
# More than 58.037033796310425s of computation time...
# More than 58.04769992828369s of computation time...
# More than 58.058104515075684s of computation time...
# More than 58.06849789619446s of computation time...
# More than 58.078797340393066s of computation time...
# More than 58.08921694755554s of computation time...
# More than 58.099560022354126s of computation time...
# More than 58.10988736152649s of computation time...
# More than 58.120290756225586s of computation time...
# More than 58.130608558654785s of computation time...
# More than 58.14100885391235s of computation time...
# More than 58.15146350860596s of computation time...
# More than 58.16189908981323s of computation time...
# More than 58.17226481437683s of computation time...
# More than 58.1831271648407s of computation time...
# More than 58.19379186630249s of computation time...
# More than 58.20480728149414s of computation time...
# More than 58.21519207954407s of computation time...
# More than 58.225553035736084s of computation time...
# More than 58.23639988899231s of computation time...
# More than 58.24693536758423s of computation time...
# More than 58.257550954818726s of computation time...
# More than 58.268165588378906s of computation time...
# More than 58.27862095832825s of computation time...
# More than 58.289204597473145s of computation time...
# More than 58.29965329170227s of computation time...
# More than 58.31028413772583s of computation time...
# More than 58.32140302658081s of computation time...
# More than 58.33199715614319s of computation time...
# More than 58.342472553253174s of computation time...
# More than 58.3531928062439s of computation time...
# More than 58.36356711387634s of computation time...
# More than 58.37382197380066s of computation time...
# More than 58.3841187953949s of computation time...
# More than 58.39434504508972s of computation time...
# More than 58.40503740310669s of computation time...
# More than 58.4153037071228s of computation time...
# More than 58.42566633224487s of computation time...
# More than 58.436198711395264s of computation time...
# More than 58.446537494659424s of computation time...
# More than 58.45691776275635s of computation time...
# More than 58.467528104782104s of computation time...
# More than 58.47803854942322s of computation time...
# More than 58.488324880599976s of computation time...
# More than 58.498717069625854s of computation time...
# More than 58.50933575630188s of computation time...
# More than 58.519866943359375s of computation time...
# More than 58.53019309043884s of computation time...
# More than 58.54051399230957s of computation time...
# More than 58.55095148086548s of computation time...
# More than 58.561415672302246s of computation time...
# More than 58.571752309799194s of computation time...
# More than 58.582072257995605s of computation time...
# More than 58.59264636039734s of computation time...
# More than 58.60341262817383s of computation time...
# More than 58.613826751708984s of computation time...
# More than 58.62430381774902s of computation time...
# More than 58.634753465652466s of computation time...
# More than 58.6452202796936s of computation time...
# More than 58.655590534210205s of computation time...
# More than 58.66616129875183s of computation time...
# More than 58.67662191390991s of computation time...
# More than 58.68700432777405s of computation time...
# More than 58.697394371032715s of computation time...
# More than 58.707868814468384s of computation time...
# More than 58.718398332595825s of computation time...
# More than 58.72893476486206s of computation time...
# More than 58.74001860618591s of computation time...
# More than 58.75049829483032s of computation time...
# More than 58.76097106933594s of computation time...
# More than 58.77143096923828s of computation time...
# More than 58.78172540664673s of computation time...
# More than 58.79213356971741s of computation time...
# More than 58.802855253219604s of computation time...
# More than 58.813220739364624s of computation time...
# More than 58.82366466522217s of computation time...
# More than 58.83405590057373s of computation time...
# More than 58.84466600418091s of computation time...
# More than 58.85499596595764s of computation time...
# More than 58.865398645401s of computation time...
# More than 58.87578344345093s of computation time...
# More than 58.88640785217285s of computation time...
# More than 58.896750926971436s of computation time...
# More than 58.90716910362244s of computation time...
# More than 58.91763210296631s of computation time...
# More than 58.928144693374634s of computation time...
# More than 58.93845081329346s of computation time...
# More than 58.9487566947937s of computation time...
# More than 58.959285736083984s of computation time...
# More than 58.96992778778076s of computation time...
# More than 58.98023056983948s of computation time...
# More than 58.991180419921875s of computation time...
# More than 59.0015230178833s of computation time...
# More than 59.012051582336426s of computation time...
# More than 59.02243733406067s of computation time...
# More than 59.0327684879303s of computation time...
# More than 59.043270111083984s of computation time...
# More than 59.053709745407104s of computation time...
# More than 59.06467652320862s of computation time...
# More than 59.0750367641449s of computation time...
# More than 59.0855073928833s of computation time...
# More than 59.09580874443054s of computation time...
# More than 59.1061589717865s of computation time...
# More than 59.11649441719055s of computation time...
# More than 59.126919984817505s of computation time...
# More than 59.13727784156799s of computation time...
# More than 59.147666692733765s of computation time...
# More than 59.158013105392456s of computation time...
# More than 59.16834497451782s of computation time...
# More than 59.1786425113678s of computation time...
# More than 59.18907594680786s of computation time...
# More than 59.199381828308105s of computation time...
# More than 59.20990753173828s of computation time...
# More than 59.22038125991821s of computation time...
# More than 59.23074531555176s of computation time...
# More than 59.24108147621155s of computation time...
# More than 59.251564741134644s of computation time...
# More than 59.2620894908905s of computation time...
# More than 59.27248001098633s of computation time...
# More than 59.28290796279907s of computation time...
# More than 59.29355525970459s of computation time...
# More than 59.3040406703949s of computation time...
# More than 59.314393043518066s of computation time...
# More than 59.32468104362488s of computation time...
# More than 59.335455656051636s of computation time...
# More than 59.34577393531799s of computation time...
# More than 59.35613393783569s of computation time...
# More than 59.36838126182556s of computation time...
# More than 59.37864303588867s of computation time...
# More than 59.38921022415161s of computation time...
# More than 59.39950895309448s of computation time...
# More than 59.40986609458923s of computation time...
# More than 59.4205379486084s of computation time...
# More than 59.431095123291016s of computation time...
# More than 59.441662549972534s of computation time...
# More than 59.452638149261475s of computation time...
# More than 59.46356678009033s of computation time...
# More than 59.47393083572388s of computation time...
# More than 59.48426842689514s of computation time...
# More than 59.49492812156677s of computation time...
# More than 59.50526785850525s of computation time...
# More than 59.51556158065796s of computation time...
# More than 59.525970458984375s of computation time...
# More than 59.53633117675781s of computation time...
# More than 59.54664993286133s of computation time...
# More than 59.55704998970032s of computation time...
# More than 59.56741452217102s of computation time...
# More than 59.57780194282532s of computation time...
# More than 59.58815574645996s of computation time...
# More than 59.5983943939209s of computation time...
# More than 59.608797550201416s of computation time...
# ...
# More than 82.4689564704895s of computation time...
# More than 82.47941946983337s of computation time...
# More than 82.4899070262909s of computation time...
# More than 82.50081777572632s of computation time...
# More than 82.51154732704163s of computation time...
# More than 82.52190971374512s of computation time...
# More than 82.53246760368347s of computation time...
# More than 82.54296255111694s of computation time...
# More than 82.55343079566956s of computation time...
# More than 82.56392049789429s of computation time...
# More than 82.5744001865387s of computation time...
# More than 82.58503651618958s of computation time...
# More than 82.59618306159973s of computation time...
# More than 82.60680818557739s of computation time...
# More than 82.61794424057007s of computation time...
# More than 82.62853646278381s of computation time...
# More than 82.63902258872986s of computation time...
# More than 82.64965295791626s of computation time...
# More than 82.66017246246338s of computation time...
# More than 82.67064023017883s of computation time...
# More than 82.68124079704285s of computation time...
# More than 82.69182062149048s of computation time...
# More than 82.70244717597961s of computation time...
# More than 82.71287965774536s of computation time...
# More than 82.72344183921814s of computation time...
# More than 82.73465991020203s of computation time...
# More than 82.74585914611816s of computation time...
# More than 82.75665140151978s of computation time...
# More than 82.76737713813782s of computation time...
# More than 82.77776384353638s of computation time...
# More than 82.78819799423218s of computation time...
# More than 82.79948425292969s of computation time...
# More than 82.80991983413696s of computation time...
# More than 82.8205771446228s of computation time...
# More than 82.83149337768555s of computation time...
# More than 82.84299516677856s of computation time...
# More than 82.85396766662598s of computation time...
# More than 82.86460876464844s of computation time...
# More than 82.8751208782196s of computation time...
# More than 82.88583970069885s of computation time...
# More than 82.89623975753784s of computation time...
# More than 82.90706205368042s of computation time...
# More than 82.91764712333679s of computation time...
# More than 82.92838382720947s of computation time...
# More than 82.93909096717834s of computation time...
# More than 82.95020246505737s of computation time...
# More than 82.96076464653015s of computation time...
# More than 82.97127532958984s of computation time...
# More than 82.98174285888672s of computation time...
# More than 82.99222016334534s of computation time...
# More than 83.00287365913391s of computation time...
# More than 83.01351356506348s of computation time...
# More than 83.02430558204651s of computation time...
# More than 83.03476452827454s of computation time...
# More than 83.04533672332764s of computation time...
# More than 83.05576705932617s of computation time...
# More than 83.06643438339233s of computation time...
# More than 83.07724332809448s of computation time...
# More than 83.08769035339355s of computation time...
# More than 83.09819960594177s of computation time...
# More than 83.10869336128235s of computation time...
# More than 83.11919116973877s of computation time...
# More than 83.12963008880615s of computation time...
# More than 83.1401801109314s of computation time...
# More than 83.15089440345764s of computation time...
# More than 83.16150641441345s of computation time...
# More than 83.17210221290588s of computation time...
# More than 83.18288803100586s of computation time...
# More than 83.19330930709839s of computation time...
# More than 83.20385432243347s of computation time...
# More than 83.21486639976501s of computation time...
# More than 83.22552537918091s of computation time...
# More than 83.2359139919281s of computation time...
# More than 83.24647355079651s of computation time...
# More than 83.25752806663513s of computation time...
# More than 83.26810622215271s of computation time...
# More than 83.27859950065613s of computation time...
# More than 83.28915023803711s of computation time...
# More than 83.29998350143433s of computation time...
# More than 83.31057786941528s of computation time...
# More than 83.32102966308594s of computation time...
# More than 83.33154129981995s of computation time...
# More than 83.34220504760742s of computation time...
# More than 83.35244512557983s of computation time...
# More than 83.36261177062988s of computation time...
# More than 83.37292146682739s of computation time...
# More than 83.38320994377136s of computation time...
# More than 83.39343118667603s of computation time...
# More than 83.40366625785828s of computation time...
# More than 83.41388440132141s of computation time...
# More than 83.42407751083374s of computation time...
# More than 83.43434309959412s of computation time...
# More than 83.4446268081665s of computation time...
# More than 83.45485043525696s of computation time...
# More than 83.46526408195496s of computation time...
# More than 83.47583889961243s of computation time...
# More than 83.48636770248413s of computation time...
# More than 83.49676203727722s of computation time...
# More than 83.50725436210632s of computation time...
# More than 83.51774597167969s of computation time...
# More than 83.52830028533936s of computation time...
# More than 83.53879976272583s of computation time...
# More than 83.55011987686157s of computation time...
# More than 83.56079745292664s of computation time...
# More than 83.57138681411743s of computation time...
# More than 83.58240532875061s of computation time...
# More than 83.59285759925842s of computation time...
# More than 83.60331225395203s of computation time...
# More than 83.61376166343689s of computation time...
# More than 83.6242287158966s of computation time...
# More than 83.63488507270813s of computation time...
# More than 83.64523005485535s of computation time...
# More than 83.6557068824768s of computation time...
# More than 83.66647243499756s of computation time...
# More than 83.67693853378296s of computation time...
# More than 83.68752336502075s of computation time...
# More than 83.7011661529541s of computation time...
# More than 83.71167731285095s of computation time...
# More than 83.7221953868866s of computation time...
# More than 83.73312544822693s of computation time...
# More than 83.74381828308105s of computation time...
# More than 83.75445222854614s of computation time...
# More than 83.76560115814209s of computation time...
# More than 83.77668929100037s of computation time...
# More than 83.7872519493103s of computation time...
# More than 83.79785990715027s of computation time...
# More than 83.80848598480225s of computation time...
# More than 83.81906342506409s of computation time...
# More than 83.82969951629639s of computation time...
# More than 83.84067893028259s of computation time...
# More than 83.85112357139587s of computation time...
# More than 83.86178731918335s of computation time...
# More than 83.87239503860474s of computation time...
# More than 83.8830246925354s of computation time...
# More than 83.89347100257874s of computation time...
# More than 83.90412950515747s of computation time...
# More than 83.9144172668457s of computation time...
# More than 83.9246883392334s of computation time...
# More than 83.9349353313446s of computation time...
# More than 83.94527912139893s of computation time...
# More than 83.9556131362915s of computation time...
# More than 83.96594309806824s of computation time...
# More than 83.9763810634613s of computation time...
# More than 83.98740029335022s of computation time...
# More than 83.99790120124817s of computation time...
# More than 84.00839734077454s of computation time...
# More than 84.01880621910095s of computation time...
# More than 84.02970600128174s of computation time...
# More than 84.040363073349s of computation time...
# More than 84.05084347724915s of computation time...
# More than 84.06115436553955s of computation time...
# More than 84.07164597511292s of computation time...
# More than 84.08218669891357s of computation time...
# More than 84.09272575378418s of computation time...
# More than 84.10317778587341s of computation time...
# More than 84.11355233192444s of computation time...
# More than 84.12394428253174s of computation time...
# More than 84.13427495956421s of computation time...
# More than 84.14478182792664s of computation time...
# More than 84.15548706054688s of computation time...
# More than 84.1666328907013s of computation time...
# More than 84.17755699157715s of computation time...
# More than 84.1880669593811s of computation time...
# More than 84.19887971878052s of computation time...
# More than 84.2093653678894s of computation time...
# More than 84.21990132331848s of computation time...
# More than 84.23034453392029s of computation time...
# More than 84.2408835887909s of computation time...
# More than 84.25341010093689s of computation time...
# More than 84.2639844417572s of computation time...
# More than 84.27436184883118s of computation time...
# More than 84.28478860855103s of computation time...
# More than 84.2953052520752s of computation time...
# More than 84.30573582649231s of computation time...
# More than 84.31625533103943s of computation time...
# More than 84.32690739631653s of computation time...
# More than 84.3374285697937s of computation time...
# More than 84.34822845458984s of computation time...
# More than 84.35881233215332s of computation time...
# More than 84.3692798614502s of computation time...
# More than 84.37962746620178s of computation time...
# More than 84.39008140563965s of computation time...
# More than 84.40071725845337s of computation time...
# More than 84.41117095947266s of computation time...
# More than 84.4216639995575s of computation time...
# More than 84.43252515792847s of computation time...
# More than 84.44365811347961s of computation time...
# More than 84.45416164398193s of computation time...
# More than 84.46481156349182s of computation time...
# More than 84.47534227371216s of computation time...
# More than 84.48582363128662s of computation time...
# More than 84.49644947052002s of computation time...
# More than 84.50689363479614s of computation time...
# More than 84.5175142288208s of computation time...
# More than 84.52809977531433s of computation time...
# More than 84.53862190246582s of computation time...
# More than 84.54923009872437s of computation time...
# More than 84.55967879295349s of computation time...
# More than 84.57008051872253s of computation time...
# More than 84.58050107955933s of computation time...
# More than 84.59084916114807s of computation time...
# More than 84.60147547721863s of computation time...
# More than 84.61223268508911s of computation time...
# More than 84.62261891365051s of computation time...
# More than 84.63309144973755s of computation time...
# More than 84.64359211921692s of computation time...
# More than 84.65394496917725s of computation time...
# More than 84.66466212272644s of computation time...
# More than 84.67516350746155s of computation time...
# More than 84.68562340736389s of computation time...
# More than 84.69634318351746s of computation time...
# More than 84.70707750320435s of computation time...
# More than 84.71749424934387s of computation time...
# More than 84.72795820236206s of computation time...
# More than 84.73846316337585s of computation time...
# More than 84.7490303516388s of computation time...
# More than 84.75943803787231s of computation time...
# More than 84.76992440223694s of computation time...
# More than 84.78034615516663s of computation time...
# More than 84.79090571403503s of computation time...
# More than 84.80139946937561s of computation time...
# More than 84.81181144714355s of computation time...
# More than 84.8230562210083s of computation time...
# More than 84.83348941802979s of computation time...
# More than 84.8439667224884s of computation time...
# More than 84.85458087921143s of computation time...
# More than 84.86519885063171s of computation time...
# More than 84.87574815750122s of computation time...
# More than 84.88618564605713s of computation time...
# More than 84.89669966697693s of computation time...
# More than 84.90768814086914s of computation time...
# More than 84.91825485229492s of computation time...
# More than 84.92864918708801s of computation time...
# More than 84.93911838531494s of computation time...
# More than 84.94954371452332s of computation time...
# More than 84.95999526977539s of computation time...
# More than 84.97047019004822s of computation time...
# More than 84.9810140132904s of computation time...
# More than 84.99146008491516s of computation time...
# More than 85.00193786621094s of computation time...
# More than 85.01241302490234s of computation time...
# More than 85.02284646034241s of computation time...
# More than 85.03360414505005s of computation time...
# More than 85.0445384979248s of computation time...
# More than 85.05507850646973s of computation time...
# More than 85.06575322151184s of computation time...
# More than 85.07696151733398s of computation time...
# More than 85.087473154068s of computation time...
# More than 85.09866404533386s of computation time...
# More than 85.10906982421875s of computation time...
# More than 85.1216402053833s of computation time...
# More than 85.13214254379272s of computation time...
# More than 85.14249849319458s of computation time...
# More than 85.15289354324341s of computation time...
# More than 85.16335105895996s of computation time...
# More than 85.1737949848175s of computation time...
# More than 85.18416285514832s of computation time...
# More than 85.19461011886597s of computation time...
# More than 85.20512700080872s of computation time...
# More than 85.21566462516785s of computation time...
# More than 85.22607731819153s of computation time...
# More than 85.23656177520752s of computation time...
# More than 85.24694633483887s of computation time...
# More than 85.25734233856201s of computation time...
# More than 85.2677538394928s of computation time...
# More than 85.27815389633179s of computation time...
# More than 85.28914523124695s of computation time...
# More than 85.29957294464111s of computation time...
# More than 85.31010890007019s of computation time...
# More than 85.3208601474762s of computation time...
# More than 85.33169150352478s of computation time...
# More than 85.342360496521s of computation time...
# More than 85.35301613807678s of computation time...
# More than 85.36348938941956s of computation time...
# More than 85.37401223182678s of computation time...
# More than 85.38451886177063s of computation time...
# More than 85.39493536949158s of computation time...
# More than 85.40549445152283s of computation time...
# More than 85.41590857505798s of computation time...
# More than 85.4263551235199s of computation time...
# More than 85.4367687702179s of computation time...
# More than 85.44733119010925s of computation time...
# More than 85.45785403251648s of computation time...
# More than 85.46844983100891s of computation time...
# More than 85.47919797897339s of computation time...
# More than 85.4896330833435s of computation time...
# More than 85.50019764900208s of computation time...
# More than 85.51063537597656s of computation time...
# More than 85.52130246162415s of computation time...
# More than 85.5318500995636s of computation time...
# More than 85.54232954978943s of computation time...
# More than 85.55279994010925s of computation time...
# More than 85.56324219703674s of computation time...
# More than 85.57370734214783s of computation time...
# More than 85.5841236114502s of computation time...
# More than 85.59498715400696s of computation time...
# More than 85.60581064224243s of computation time...
# More than 85.61630272865295s of computation time...
# More than 85.62668204307556s of computation time...
# More than 85.6377067565918s of computation time...
# More than 85.6482241153717s of computation time...
# More than 85.65860748291016s of computation time...
# More than 85.669016122818s of computation time...
# More than 85.67938661575317s of computation time...
# More than 85.6902015209198s of computation time...
# More than 85.70077085494995s of computation time...
# More than 85.71117329597473s of computation time...
# Total word in the dataset: 2038444
# Computation took 85.71162271499634s

# %% [markdown]
# Distributed version:

# %%
client = Client() #change your setting
# Out:
# /home/lorenzo/.local/lib/python3.8/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40613 instead
#   warnings.warn(

# %%
import time
start = time.time()

futures = [client.submit(count_word_in_statement, data) for data in dataset]
futures = client.submit(sum, futures)
total_words_in_all_data = client.gather(futures)

    
end = time.time()
print("Total word in the dataset: {}".format(total_words_in_all_data))
print("Computation took {}s".format(end-start))
# Out:
# Total word in the dataset: 2038444
# Computation took 13.156180381774902s

# %%
client.close()

# %% [markdown]
# What happens if we increment the number of workers or threads per worker?

# %% [markdown]
# If you feel like a hero and you don't be afraid to become old by standing in front of the PC, you can try to compare the sequential code and the distributed code by increasing the sleep time 100ms or 1s

# %% [markdown]
# ### How works the distribution and the scheduling of the processes?
#
# #### How a worker is choosen?
# Even though you can reduce and make some restrictions, e.g: restriction over worker resources, Dask automatically decides the suitable workers for your tasks by figuring out the optimized worker for each task.
# This means that, if a task has significant data dependencies or if the workers are under heavy load then this choice of worker can strongly impact global performance because the decision becomes heavy.
#
# Dask follows the following rules before to assign a task to a worker:
# + If the task has no major dependencies and no restrictions then we find the least occupied worker.
#
# + if a task has user-provided restrictions (for example it must run on a machine with a GPU) then we restrict the available pool of workers to just that set, otherwise, we consider all workers
# + from the pool of workers Dask determinates the workers to whom the least amount of data would need to be transferred (means less overhead on the cluster and hence computation optimization).
# +  if some dependencies in the graph can be broken the will be assigned to the worker that currently has the fewest tasks.
#
#
# Dask also allows modifying the worker decision function in order to be more flexible and to improve the customization of a cluster. This means that particular processes or particular computational fields in which performances can be improved by customizing and optimizing the task's assignation decision can be made more performant.
#
# Breaking the dependencies in some cases is necessary, especially if each node has a lot of sons. In this case, each node with his sons must be removed from the graph and computed alone. This has a huge impact on performances and memory. On the other hand, this means that when a user submits a task, the computation graph must be scan to figuring out and optimizing this kind of dependencies.
#
#
# #### How choose the next task?
# Typically Dask follows those rules in order to choose the next task that must be executed:
# + Run tasks on a first-come-first-served basis for fairness between multiple clients
# + Run tasks that are part of the critical path in an effort to reduce total running time and minimize straggler workloads
# + Run tasks that allow us to release many dependencies in an effort to keep the memory footprint small
# + Run tasks that are related so that large chunks of work can be completely eliminated before running new chunks of work
#
# As you can see a part of the overhead on a cluster is principally caused by the optimization of the execution task decision. Even though these are rules implemented by Dask, in general, the majority of the Cluster, even if they are based on other frameworks and other architectures, follow the same similar approaches.
#
# On the other hand, some computational fields may require a different approach to decide which tasks can be executed, e.g: by using last-in-first-out approach or by giving a priority to each task in order to execute first some processes.
#
# In some cases, Dask optimization exploit also a partially last-in-first-out approach. When a worker finishes a task the immediate dependencies of that task get top priority. This encourages a behavior of finishing ongoing work immediately before starting new work. This often conflicts with the first-come-first-served objective but often results in shorter total runtimes and significantly reduced memory footprints.
#
#
# #### Where these decisions are made?
#
# The decision are basically made ina small steps and in a different computation steps by client, scheduler, and workers:
#
# + As we submit a graph from the *client* to the scheduler we automatically assign a numeric priority to each task of that graph. This priority focuses on computing deeply before broadly, preferring critical paths, and preferring nodes with many dependencies.
#
# + When the graph reaches the scheduler the scheduler changes each of these numeric priorities into a tuple of two numbers, the first of which is an increasing counter, the second of which is the client-generated priority described above. This per-graph counter encourages a first-in-first-out policy between computations. All tasks from a previous call to compute have a higher priority than all tasks from a subsequent call to compute (or submit, persist, map, or any operation that generates futures).
#
# + Whenever a task is ready to run the scheduler assigns it to a worker. The scheduler does not wait based on priority. However when the worker receives these tasks it considers their priorities when determining which tasks to prioritize for communication or for computation.

# %% [markdown]
# ### Worker Resources
#
# Let's suppose that you want to run a proces over a cluster, but only in those machine that has a GPU or have at least 16Gb of RAM. Now let's imagin that you have a cluster of ten computers in which four have a GPU while the others no. In this case we want to balance tasks across the cluster with these resource constraints in mind, allocating GPU-constrained tasks to GPU-enabled workers. Additionally we need to be sure to constrain the number of GPU tasks that run concurrently on any given worker to ensure that we respect the provided limits.
# Clearly, this situation arises not only for GPUs but for many resources like tasks that require a large amount of memory at runtime, special disk access, or access to special hardware.

# %% [markdown]
# When you require workers with particular resources you must be sure that those resources are availables over the cluster.
# Otherwise your processes should be never executed.
#
# Let's try an example togheter:

# %% [markdown]
# At first, stop the workers that you have in your cluster and the scheduler. Start again the scheduler and then turn up two workers with those commands:
#
# + ```dask-worker dask-scheduler:8786 --nprocs 1 --nthreads 1 --resources "GPU=2"```
# + ```dask-worker dask-scheduler:8786 --nprocs 1 --nthreads 1 --resources "GPU=1"```

# %%
import numpy as np
from dask.distributed import Client

client = Client() ##change your settings
# Out:
# /home/lorenzo/.local/lib/python3.8/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39077 instead
#   warnings.warn(

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:42877' processes=4 threads=8, memory=7.56 GiB>

# %%
matrices = []

for i in range(100):
    matrices.append(np.random.rand(4,3))

def compute_polynomial_kernel(matrix):
    polynomial_degree = 2
    return np.power((np.dot(matrix, matrix.T)+1), 2)

# %% [markdown]
# Since we are working on a matrix computation let's suppose that we want exploit the multi-gpu available only on some workers.
# Assume that we need to use 3 GPUs:

# %%
processed = [client.submit(compute_polynomial_kernel, matrix, resources={'GPU': 3}) for matrix in matrices]

kernels = client.gather(processed)

for i in kernels:
    print("Kernel is: {}".format(i))
    print()
client.close()

# %%
client.close()

# %% [markdown]
# nothing is happening but the code still running...... Let's try to add on-the-fly a worker with 3 GPUs
#
# ```dask-worker 192.168.1.12:8786 --nprocs 1 --nthreads 1 --resources "GPU=3"```

# %% [markdown]
# ### Exercise 1:
#
# Compute the traces of all the generated matrix. Execute this code over 2 workers with 2 "SpecialCPU" each one.
# You must use the ```map``` function.

# %%
import numpy as np
matrices = [np.random.randint(low=m, high=m+1, size=(4, 3)) for m in (range(11))]

# %%
#dask-worker scheduler:8786 --nprocs 2 --resources "GPU=2" command to be run for the process to start

processed = [client.submit(np.trace, matrix, resources={'GPU': 2}) for matrix in matrices]

print(client.gather(processed))

cmap = client.map(np.trace, matrices, resources = {'GPU':2})

print(client.gather(cmap))
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30]

# %% [markdown]
# ### Exercise 2:
#
# Execute the code of the "howmany_within_range" exercise from the previous lecture, into a worker with 256Gb of RAM. Map function is not allowed.

# %%
import numpy as np

## creation of a matrix of 100 rows and 10 columns with each value between 0 and 100.
np.random.RandomState(42)
arr = np.random.randint(0, 100, size=[100, 10])

from dask.distributed import Client
client = Client()
client
# Out:
# /home/lorenzo/.local/lib/python3.8/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38231 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:34135' processes=4 threads=8, memory=7.56 GiB>

# %%
def howmany_within_range(row):
    """Returns how many numbers lie within 0 and 10 in the given `row`"""
    count = 0
    for n in row:
        if 0 <= n <= 10:
            count = count + 1
    return count

#necessary command for cell execution
#dask-worker  scheduler:port --nprocs 2 --resources "MEMORY=256e9"

futures = [client.submit(howmany_within_range, matrix, resources={'MEMORY': 256e9}) for matrix in arr]

results = client.gather(futures)
print(results)

client.close()
# Out:
# [0, 0, 1, 1, 2, 1, 1, 0, 1, 0, 2, 0, 1, 1, 0, 0, 0, 1, 1, 0, 2, 0, 2, 2, 1, 1, 0, 3, 1, 2, 1, 3, 1, 2, 2, 1, 2, 1, 1, 0, 0, 3, 0, 1, 0, 2, 1, 1, 1, 1, 0, 0, 1, 2, 2, 0, 1, 4, 2, 0, 4, 0, 2, 1, 0, 1, 1, 4, 0, 0, 1, 2, 2, 2, 1, 1, 0, 1, 1, 0, 0, 1, 2, 0, 0, 1, 0, 1, 1, 2, 2, 0, 0, 0, 1, 2, 2, 1, 1, 1]
